# %% [markdown]
# # Identifying Confusion Amongst Python Programmers
#
# An interactive introduction to data science workflows.

# %% [markdown]
# ## Introduction

# %% [markdown]
# This is a Jupyter notebook.  It allows you to program interactively using both Python and Markdown (you can set individual cells of text to be either).  It has two modes: command mode and edit mode.  Hit `ESC` + `h` to see a Help menu.

# %% [markdown]
# ## Today's Scenario

# %% [markdown]
# ## A Data Science Workflow
#
# 1. Define the question and goals.
# 2. Acquire the data.
# 3. Scrub the data.
# 4. Explore the data.
# 5. Model the Data (if predictions needed).
# 6. Communicate insights.
# 7. Repeat and Refine as necessary.

# %% [markdown]
# ## Step 1: Define the question and goals.

# %% [markdown]
# Harriet Human-Resources, the VP in charge of hiring and training, comes to you one day and says
#
# > We need to make our internal training programs for teaching new hires programming languages better.  We’re going to put a team on it, but they need more information about what to build when teaching them new languages. We want to focus on Python first. I know you’re busy with 100 other things, but can you give us some preliminary insight at the end of the day?
#
# ....
#
# Whew, what an ask!  Given the short timeline (deliver today) and haziness of what's asked, we will distill the question down to:
#
# **What aspects of Python programming present the most difficulties to programmers?**

# %% [markdown]
# ## Step 2: Identify and Acquire the data.

# %% [markdown]
# Stack Overflow is the world's premier software Q&A site.
#
# It organizes questions by topic tags.  One of these tags is "Python". There are almost one million questions on the Python tag: https://stackoverflow.com/questions/tagged/python.
#
# For the purposes of today's exercise, we are going to pretend that Stack Overflow's API is insufficient for our needs.  Instead, we are going to scrape the data in HTML format.
#
# You can do this using the Requests (as in HTTP) library. Requests provides a very simplistic API for making HTTP requests.
#
# In order to rapidly prototype, let's acquire just the first 5 pages of Python questions.  An examination of the Stack Overflow web app shows that this information lives at the URLs that look like this:
#
# https://stackoverflow.com/questions/tagged/python?page=5&sort=votes&pagesize=15
#
# See the `page=5` and `pagesize=15` query parameters?
#
# Put all of this information together and use Python's built-in `open` function to scrape Stack Overflow's data to files in the `data/raw` diretory:

# %%
import requests

page_range = range(1, 6)
so_url = "https://stackoverflow.com/questions/tagged/python?page={0}&sort=votes&pagesize=15"
raw_file = 'data/raw/PAGE_{0}.html'

for page_number in page_range:
        response = requests.get(so_url.format(page_number))
        
        if response.status_code == 200:
            with open(raw_file.format(page_number), 'w') as f:
                f.write(response.text)  
        else:
            print("FAILED at {0} with status code {1}".format(page_number, response.status_code))

# %% [markdown]
# ## Step 3: Clean/Wrangle the data.

# %% [markdown]
# Beautiful Soup is the most popular Python library for parsing HTML.  It parses HTML files into a tree-like Python data structure.
#
# It works like this:

# %%
from bs4 import BeautifulSoup

with open('data/raw/PAGE_1.html', 'r') as f:
    soup = BeautifulSoup(f.read(), 'html.parser')
    questions = soup.find_all("h1")
    print(questions[0].text)
# Out:
# Tagged Questions

# %% [markdown]
# Look at the stack overflow page and think about the information contained on that page: What are the granular data points we want to extract?  What is the top-level real-world object?
#
#
# Here, it is the question object.  Some of the attributes of a question object that you can see on the page are:
# - question text
# - vote score
# - views
# - details
# - author
# - question details
# - date
#
# Let's think about this question from the top-down.  We basically want each of these question attributes grouped together in an object.  For purposes of developing our initial data structure, we can parse out 250 question objects into an array.  We basically want to be able to write code that looks like this:
#
# ```
# dataset = []
#
# for i in page_range:
#     filename = "data/raw/FILENAME_{}.html".format(i)
#     qs = extract_question_objects(filename)
#     dataset.extend(qs)
#
# ```
#
# Let's write some supporting functions for this loop first:

# %%
def get_question_info_from_summary(summary_div):
    """
        :summary_div: A BS4 Tag Object 
    """
    qid = summary_div['id'].split("-")[2]
    text = summary_div.find('a', class_="question-hyperlink").text
    tags = [tag.text for tag in summary_div.find_all('a', class_="post-tag")]
    views = int(summary_div.find('div', class_="views")['title'].split(" ")[0].replace(",", ""))
    votes = int(summary_div.find('span', class_="vote-count-post").find('strong').text)

    # data isn't always there
    date = summary_div.find('span', class_='relativetime')
    date_asked = date['title'] if date else None
    
    return [qid, views, text, tags, date_asked, votes]


def extract_question_objects(relative_html_path):
    """
        :relative_html_path: file to read and parse for stack overflow questions
    """
    questions_objects = []
    with open(relative_html_path, 'r') as f:
    
        soup = BeautifulSoup(f.read(), 'html.parser')
        question_divs = soup.find_all("div", class_="question-summary")

        for question in question_divs:
                q_info = get_question_info_from_summary(question)
                questions_objects.append(q_info)
    
    
    return questions_objects

# %% [markdown]
# Now let's run that top-down code:

# %%
dataset = []

for i in page_range:
    filename = "data/raw/PAGE_{}.html".format(i)
    qs = extract_question_objects(filename)
    dataset.extend(qs)

#  uncomment for fun
# print(len(dataset))
# print(dataset[0])

# %% [markdown]
# ## Step 4: Explore the data.

# %% [markdown]
# One of the first things we want to do is get this data into a data structure known as a Pandas DataFrame.
#
# Pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with relational (“labeled”) data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language. It is already well on its way toward this goal.
#
# The `DataFrame` is  the primary Pandas data structure.  They are great for exploring about tabular data - think columns and rows.

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(columns=['views', 'text', 'tags', 'date_asked', 'votes'] )

for data in dataset:
    qid, views, text, tags, date_asked, votes = data
    df.loc[qid] = [views, text, tuple(np.array(tags)), date_asked, votes]


df
# Out:
#             views                                               text  \
# 231767    1569404                  What does the “yield” keyword do?
# 100003     559107                    What are metaclasses in Python?
# 82831     2507025  How do I check whether a file exists using Pyt...
# 394809    1183741   Does Python have a ternary conditional operator?
# 419163    1484074           What does if __name__ == “__main__”: do?
# 89228     2291705              Calling an external command in Python
# 38987     1003099  How to merge two dictionaries in a single expr...
# 613183    1578035               How do I sort a dictionary by value?
# 273192    1610563  How can I create a directory if it does not ex...
# 3437059   2168732  Does Python have a string 'contains' substring...
# 3207219   2028116            How do I list all files of a directory?
# 53513     1462118                 How do I check if a list is empty?
# 252703    1924220  Difference between append vs. extend list meth...
# 136097     472815  What is the difference between @staticmethod a...
# 739654     413223        How to make a chain of function decorators?
# 522563    1133026          Accessing the index in Python 'for' loops
# 423379    2402371  Using global variables in a function other tha...
# 4750806   2102425                   How do I install pip on Windows?
# 509211    1000225              Understanding Python's slice notation
# 176918    2151811  Finding the index of an item given a list cont...
# 986006     863148             How do I pass a variable by reference?
# 1436703    414120  Difference between __str__ and __repr__ in Python
# 1602934   1855037  Check if a given key already exists in a dicti...
# 1132941    103930  “Least Astonishment” and the Mutable Default A...
# 576169    1178350  Understanding Python super() with __init__() m...
# 3294889   2428752      Iterating over dictionaries using 'for' loops
# 952914     957121  Making a flat list out of list of lists in Python
# 6470428    394510  Catch multiple exceptions in one line (except ...
# 510348    1825443             How can I make a time delay in Python?
# 101754     447053           Is there a way to run Python on Android?
# ...           ...                                                ...
# 6760685    172651                     Creating a singleton in Python
# 2104080    358093                  How to check file size in python?
# 5142418    358168             What is the use of “assert” in Python?
# 2632677    627095    Python integer incrementing with ++ [duplicate]
# 120656     514203                        Directory listing in Python
# 9257094    754776              How to change a string into uppercase
# 247770     345467                      Retrieving python module path
# 988228     397945  Convert a String representation of a Dictionar...
# 403421     278896  How to sort a list of objects based on an attr...
# 6667201   1340871    How to define a two-dimensional array in Python
# 2710940    405473   Python `if x is not None` or `if not x is None`?
# 972        151134     Adding a Method to an Existing Object Instance
# 132988     204928  Is there a difference between `==` and `is` in...
# 1059559    406198            Split Strings with Multiple Delimiters?
# 441147     296819       How can I subtract a day from a Python date?
# 1118183    169629              How to debug in Django, the good way?
# 431684     621475                           How do I “cd” in Python?
# 4260280    319287            if/else in Python's list comprehension?
# 1663807    321907      How to iterate through two lists in parallel?
# 687295     219954  How do I do a not equal in Django queryset fil...
# 4426663    483750  How do I remove the first Item from a Python l...
# 976882     522135                        Shuffling a list of objects
# 2967194    571820  open() in Python does not create a file if it ...
# 2802726    575531  Putting a simple if-then statement on one line...
# 842059     236866  Is there a portable way to get the current use...
# 31421379    27376  Why does “not(True) in [False, True]” return F...
# 472000     114525                                Usage of __slots__?
# 12555323   780894  Adding new column to existing DataFrame in Pyt...
# 4344017    530199  How can I get the concatenation of two lists i...
# 311627     814470   How to print date in a regular format in Python?
#
#                                                        tags  \
# 231767      (python, iterator, generator, yield, coroutine)
# 100003           (python, oop, metaclass, python-datamodel)
# 82831                           (python, file, filesystems)
# 394809    (python, operators, ternary-operator, conditio...
# 419163           (python, module, namespaces, main, idioms)
# 89228        (python, shell, command, subprocess, external)
# 38987     (python, python-3.x, dictionary, mapping, idioms)
# 613183                        (python, sorting, dictionary)
# 273192                       (python, exception, directory)
# 3437059               (python, string, substring, contains)
# 3207219                                 (python, directory)
# 53513                                        (python, list)
# 252703      (python, list, data-structures, append, extend)
# 136097            (python, oop, methods, python-decorators)
# 739654               (python, decorator, python-decorators)
# 522563                                (python, loops, list)
# 423379                    (python, global-variables, scope)
# 4750806   (python, windows, installation, pip, easy-inst...
# 509211                                (python, list, slice)
# 176918                             (python, list, indexing)
# 986006    (python, reference, parameter-passing, pass-by...
# 1436703                                      (python, repr)
# 1602934                                (python, dictionary)
# 1132941       (python, language-design, least-astonishment)
# 576169                    (python, oop, inheritance, super)
# 3294889                    (python, python-2.7, dictionary)
# 952914      (python, list, multidimensional-array, flatten)
# 6470428             (python, exception, exception-handling)
# 510348                           (python, sleep, timedelay)
# 101754    (android, python, jython, ase, android-scripting)
# ...                                                     ...
# 6760685   (python, singleton, decorator, base-class, met...
# 2104080                                           (python,)
# 5142418                        (python, assert, assertions)
# 2632677                                    (python, syntax)
# 120656                                (python, filesystems)
# 9257094                         (python, string, uppercase)
# 247770                            (python, module, inotify)
# 988228                         (python, string, dictionary)
# 403421                             (python, sorting, count)
# 6667201                      (python, matrix, syntax-error)
# 2710940          (python, coding-style, boolean-expression)
# 972                  (python, oop, methods, monkeypatching)
# 132988                       (python, reference, semantics)
# 1059559                             (python, string, split)
# 441147                             (python, datetime, date)
# 1118183                         (python, django, debugging)
# 431684                                            (python,)
# 4260280                        (python, list-comprehension)
# 1663807                                  (python, iterator)
# 687295     (python, django, django-models, django-queryset)
# 4426663                              (python, arrays, list)
# 976882                      (python, list, random, shuffle)
# 2967194          (python, linux, file-io, file-permissions)
# 2802726                      (python, syntax, if-statement)
# 842059                      (python, portability, username)
# 31421379                   (python, python-2.7, python-3.x)
# 472000                                      (python, slots)
# 12555323    (python, pandas, dataframe, chained-assignment)
# 4344017   (python, concatenation, sequence, list-manipul...
# 311627                             (python, datetime, date)
#
#                     date_asked votes
# 231767    2008-10-23 22:21:11Z  7622
# 100003    2008-09-19 06:10:46Z  4184
# 82831     2008-09-17 12:55:00Z  3896
# 394809                    None  3891
# 419163    2009-01-07 04:11:00Z  3528
# 89228     2008-09-18 01:35:30Z  3238
# 38987     2008-09-02 07:44:30Z  2809
# 613183    2009-03-05 00:49:05Z  2606
# 273192    2008-11-07 18:56:45Z  2603
# 3437059   2010-08-09 02:52:50Z  2439
# 3207219   2010-07-08 19:31:22Z  2416
# 53513     2008-09-10 06:20:11Z  2407
# 252703    2008-10-31 05:55:36Z  2391
# 136097    2008-09-25 21:01:57Z  2335
# 739654    2009-04-11 07:05:31Z  2265
# 522563    2009-02-06 22:47:54Z  2253
# 423379    2009-01-08 05:45:02Z  2252
# 4750806                   None  2090
# 509211    2009-02-03 22:31:02Z  1995
# 176918    2008-10-07 01:39:38Z  1940
# 986006    2009-06-12 10:23:51Z  1905
# 1436703   2009-09-17 04:27:45Z  1901
# 1602934   2009-10-21 19:05:09Z  1899
# 1132941   2009-07-15 18:00:37Z  1897
# 576169    2009-02-23 00:30:08Z  1794
# 3294889   2010-07-20 22:27:42Z  1777
# 952914    2009-06-04 20:30:05Z  1761
# 6470428   2011-06-24 15:55:08Z  1738
# 510348    2009-02-04 07:04:09Z  1728
# 101754    2008-09-19 13:21:12Z  1719
# ...                        ...   ...
# 6760685   2011-07-20 10:47:57Z   478
# 2104080   2010-01-20 18:58:29Z   477
# 5142418   2011-02-28 13:11:45Z   477
# 2632677   2010-04-13 19:45:14Z   476
# 120656    2008-09-23 12:28:19Z   476
# 9257094   2012-02-13 07:48:56Z   476
# 247770    2008-10-29 17:52:40Z   469
# 988228    2009-06-12 18:25:02Z   467
# 403421    2008-12-31 16:41:32Z   467
# 6667201   2011-07-12 15:54:38Z   466
# 2710940   2010-04-26 03:10:30Z   466
# 972       2008-08-04 02:17:51Z   464
# 132988    2008-09-25 12:27:09Z   463
# 1059559   2009-06-29 17:49:35Z   462
# 441147    2009-01-13 22:39:36Z   462
# 1118183   2009-07-13 07:57:02Z   461
# 431684    2009-01-10 20:28:16Z   459
# 4260280   2010-11-23 19:56:44Z   459
# 1663807   2009-11-02 21:26:24Z   458
# 687295    2009-03-26 19:47:45Z   456
# 4426663   2010-12-13 07:38:38Z   453
# 976882    2009-06-10 16:56:59Z   453
# 2967194   2010-06-03 15:05:54Z   452
# 2802726   2010-05-10 12:58:04Z   448
# 842059    2009-05-08 22:20:20Z   448
# 31421379  2015-07-15 04:12:58Z   447
# 472000    2009-01-23 05:37:23Z   447
# 12555323  2012-09-23 19:00:01Z   447
# 4344017   2010-12-03 09:16:30Z   446
# 311627    2008-11-22 18:37:07Z   444
#
# [250 rows x 5 columns]

# %% [markdown]
# The Pandas DataFrame API is rich and worth exploring.

# %%
# uncomment line-by-line to explore:
# df['tags']
# df.columns
# df.index

# %% [markdown]
# ### Exploratory Data Analaysis: Pandas Profiling

# %% [markdown]
# Pandas DataFrames have some built-in data profilings...

# %%
df.describe()
# Out:
#           views                                              text       tags  \
# count       250                                               250        250
# unique      250                                               250        221
# top     1183741  How to print date in a regular format in Python?  (python,)
# freq          1                                                 1         10
#
#                   date_asked  votes
# count                    240    250
# unique                   240    213
# top     2014-02-03 15:00:16Z    483
# freq                       1      3

# %% [markdown]
# ....but the `pandas-profiling` package is more complete.  One of the first things many data scientists do is run a profile on their dataframe.  Let's do that here.

# %%
import pandas_profiling

pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>250 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.7% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>11.8 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>48.3 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code>date_asked</code> has 10 / 4.0% missing values <span class="label label-default">Missing</span></l><li><code>date_asked</code> has a high cardinality: 241 distinct values  <span class="label label-warning">Warning</span></l><li><code>tags</code> has a high cardinality: 221 distinct values  <span class="label label-warning">Warning</span></l> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4">date_asked<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="alert">
#             <th>Distinct count</th>
#             <td>241</td>
#         </tr>
#         <tr>
#             <th>Unique (%)</th>
#             <td>100.4%</td>
#         </tr>
#         <tr class="alert">
#             <th>Missing (%)</th>
#             <td>4.0%</td>
#         </tr>
#         <tr class="alert">
#             <th>Missing (n)</th>
#             <td>10</td>
#         </tr>
#     </table>
# </div>
# <div class="col-md-6 collapse in" id="minifreqtable-5371026765712743904">
#     <table class="mini freq">
#         <tr class="">
#     <th>2014-02-03 15:00:16Z</th>
#     <td>
#         <div class="bar" style="width:1%" data-toggle="tooltip" data-placement="right" data-html="true"
#              data-delay=500 title="Percentage: 0.4%">
#             &nbsp;
#         </div>
#         1
#     </td>
# </tr><tr class="">
#     <th>2010-07-18 21:40:25Z</th>
#     <td>
#         <di

# %% [markdown]
# There are plenty of interesting things to notice here.

# %% [markdown]
# ### Exploratory Data Analysis: Word Clouds

# %% [markdown]
# The real meat of the Stack Overflow data we have so far lay in question text.  Analyzing text is known as _natural language processing_.  One of the first things many data scientists do to examine text data is make a word cloud, measuring the importance of words by their relative frequencies.
#
# To get started with word clouds, we will use the Python `collections` library, most specifically its `Counter` data structure.  If you feed `Counter` an array of words, it will return a count of words frequencies.  Let's find the 100 most common words first.

# %% [markdown]
# #### Word Cloud 1: The 100 Most Common Words With `collections.Counter`

# %%
from collections import Counter

SO_words = []

for i, row in df.iterrows():
     words = row.text.split(" ")
     for word in words:
        SO_words.append(word)

# print(SO_words)

so_counter = Counter([word for word in SO_words])
most_common = so_counter.most_common(100)

print(most_common)
# Out:
# [('in', 119), ('a', 113), ('How', 89), ('Python', 78), ('to', 75), ('Python?', 49), ('the', 47), ('I', 44), ('do', 42), ('of', 41), ('is', 31), ('and', 26), ('What', 23), ('list', 22), ('with', 20), ('from', 20), ('an', 19), ('string', 19), ('can', 14), ('if', 12), ('between', 12), ('way', 12), ('does', 10), ('file', 10), ('get', 10), ('or', 10), ('Why', 10), ('check', 9), ('not', 9), ('[closed]', 9), ('using', 8), ('on', 8), ('[duplicate]', 8), ('you', 8), ('for', 8), ('are', 7), ('dictionary', 7), ('by', 7), ('directory', 7), ('pip', 7), ('lists', 7), ('Is', 7), ('there', 7), ('python', 7), ('two', 6), ('difference', 6), ('line', 6), ('remove', 6), ('use', 6), ('create', 5), ('it', 5), ('function', 5), ('install', 5), ("Python's", 5), ('variable', 5), ('over', 5), ('into', 5), ('values', 5), ('print', 5), ('file?', 5), ('object', 5), ('pandas', 5), ('sort', 4), ('all', 4), ('vs.', 4), ('multiple', 4), ('time', 4), ('current', 4), ('dictionary?', 4), ('Getting', 4), ('module', 4), ('DataFrame', 4), ('path', 4), ('vs', 4), ('do?', 3), ('exists', 3), ('Does', 3), ('have', 3), ('dictionaries', 3), ('files', 3), ('directory?', 3), ('methods', 3), ('make', 3), ('index', 3), ('variables', 3), ('than', 3), ('one', 3), ('Understanding', 3), ('item', 3), ('given', 3), ('key', 3), ('new', 3), ('list?', 3), ('class', 3), ('number', 3), ('packages', 3), ('Converting', 3), ('python?', 3), ('element', 3), ('without', 3)]

# %% [markdown]
# Let's visualize this with a wordcloud, measuring by frequency.  We will use two libraries, `matplotlib` and `wordcloud`.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# WordCloud expects a dictionary mapping words to frequencies (i.e. strings to floats).  Let's massage the data in that direction with a dict comprehension.

# %%
python_word_frequencies = {word: frequency for word, frequency in most_common}

print(python_word_frequencies)
# Out:
# {'in': 119, 'a': 113, 'How': 89, 'Python': 78, 'to': 75, 'Python?': 49, 'the': 47, 'I': 44, 'do': 42, 'of': 41, 'is': 31, 'and': 26, 'What': 23, 'list': 22, 'with': 20, 'from': 20, 'an': 19, 'string': 19, 'can': 14, 'if': 12, 'between': 12, 'way': 12, 'does': 10, 'file': 10, 'get': 10, 'or': 10, 'Why': 10, 'check': 9, 'not': 9, '[closed]': 9, 'using': 8, 'on': 8, '[duplicate]': 8, 'you': 8, 'for': 8, 'are': 7, 'dictionary': 7, 'by': 7, 'directory': 7, 'pip': 7, 'lists': 7, 'Is': 7, 'there': 7, 'python': 7, 'two': 6, 'difference': 6, 'line': 6, 'remove': 6, 'use': 6, 'create': 5, 'it': 5, 'function': 5, 'install': 5, "Python's": 5, 'variable': 5, 'over': 5, 'into': 5, 'values': 5, 'print': 5, 'file?': 5, 'object': 5, 'pandas': 5, 'sort': 4, 'all': 4, 'vs.': 4, 'multiple': 4, 'time': 4, 'current': 4, 'dictionary?': 4, 'Getting': 4, 'module': 4, 'DataFrame': 4, 'path': 4, 'vs': 4, 'do?': 3, 'exists': 3, 'Does': 3, 'have': 3, 'dictionaries': 3, 'files': 3, 'directory?': 3, 'methods': 3, 'make': 3, 'index': 3, 'variables': 3, 'than': 3, 'one': 3, 'Understanding': 3, 'item': 3, 'given': 3, 'key': 3, 'new': 3, 'list?': 3, 'class': 3, 'number': 3, 'packages': 3, 'Converting': 3, 'python?': 3, 'element': 3, 'without': 3}

# %% [markdown]
# Making the word cloud is easy:

# %%
wordcloud = WordCloud(width=800, height=400)
wordcloud.generate_from_frequencies(frequencies=most_common)
plt.figure(figsize=(20,10), facecolor='k')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
# plt.savefig('wordcloud.png') # Does this work??? Just saves black image.

# %% [markdown]
# This looks like garbage.   Let's use a list of **stop words** as a filter when we're compiling our count.

# %% [markdown]
# #### Word Cloud #2: Removing Stop Words

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = set(stopwords.words('english'))

print(stop)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-a4213856873f> in <module>()
# ----> 1 import nltk
#       2 from nltk.corpus import stopwords
#       3 nltk.download('stopwords')
#       4 stop = set(stopwords.words('english'))
#       5
#
# ModuleNotFoundError: No module named 'nltk'

# %% [markdown]
# ## Step 5: Model the data if preditions are needed.

# %% [markdown]
# We are not predicting anything today.

# %% [markdown]
# ## Step 6: Communicate insights.

# %% [markdown]
# At this point, we are pretty ready to walk into our meeting.  As John Tukey said, exploratory data analysis is an attitude.  Our attitude has now shifted to "I have a same-day meeting to deliver some insight."  At this point, you are prepared with:
# * A profile of Stack Overflow question fields, which gives business intelligence about what sort of data is readily available;
# * A word cloud that anybody can understand (visualization #1)
# * A network graph visualization of related topics Python programmers have quesitons about (visualization #2)
# * A Jupyter notebook full of replicable code to be iterated and improved upon.
